# %% [markdown]
# <a href="https://colab.research.google.com/github/peibanlioulang/Data-Analysis-Project/blob/main/DataAnalyzeProject_MovieData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Find Correlations in data
# Import Libraries

import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize']=(12,8)

# Read in the data
df = pd.read_csv('/content/movies.csv')

# %%
# Top 5 rows of the data
df.head()
# Out:
#                                              name  ... runtime
# 0                                     The Shining  ...   146.0
# 1                                 The Blue Lagoon  ...   104.0
# 2  Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                       Airplane!  ...    88.0
# 4                                      Caddyshack  ...    98.0
#
# [5 rows x 15 columns]

# %%
# Checking for missing data

for col in df.columns:
  missing = np.mean(df[col].isnull())
  print('{}-{}%'.format(col,missing))
# Out:
# name-0.0%
# rating-0.010041731872717789%
# genre-0.0%
# year-0.0%
# released-0.0002608242044861763%
# score-0.0003912363067292645%
# votes-0.0003912363067292645%
# director-0.0%
# writer-0.0003912363067292645%
# star-0.00013041210224308815%
# country-0.0003912363067292645%
# budget-0.2831246739697444%
# gross-0.02464788732394366%
# company-0.002217005738132499%
# runtime-0.0005216484089723526%

# %%
# NaN value to 0
df = df.fillna(0)

# %%
# Checking for missing data

for col in df.columns:
  missing = np.mean(df[col].isnull())
  print('{}-{}%'.format(col,missing))
# Out:
# name-0.0%
# rating-0.0%
# genre-0.0%
# year-0.0%
# released-0.0%
# score-0.0%
# votes-0.0%
# director-0.0%
# writer-0.0%
# star-0.0%
# country-0.0%
# budget-0.0%
# gross-0.0%
# company-0.0%
# runtime-0.0%

# %%
# Data types for each column

df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# change data type of columns

df['budget'] = df['budget'].astype('int64')

df['gross'] = df['gross'].astype('int64')

# %%
df
# Out:
#                                                 name  ... runtime
# 0                                        The Shining  ...   146.0
# 1                                    The Blue Lagoon  ...   104.0
# 2     Star Wars: Episode V - The Empire Strikes Back  ...   124.0
# 3                                          Airplane!  ...    88.0
# 4                                         Caddyshack  ...    98.0
# ...                                              ...  ...     ...
# 7663                                    More to Life  ...    90.0
# 7664                                     Dream Round  ...    90.0
# 7665                                   Saving Mbango  ...     0.0
# 7666                                    It's Just Us  ...   120.0
# 7667                                       Tee em el  ...   102.0
#
# [7668 rows x 15 columns]

# %%
# Get correct released Year

df['released']= df['released'].astype(str)
df[['releasedDate','releasedYear']]= df['released'].str.split(",",expand=True)
df['Year'] = df['releasedYear'].str[:5]
df
# Out:
#                                                 name  ...   Year
# 0                                        The Shining  ...   1980
# 1                                    The Blue Lagoon  ...   1980
# 2     Star Wars: Episode V - The Empire Strikes Back  ...   1980
# 3                                          Airplane!  ...   1980
# 4                                         Caddyshack  ...   1980
# ...                                              ...  ...    ...
# 7663                                    More to Life  ...   2020
# 7664                                     Dream Round  ...   2020
# 7665                                   Saving Mbango  ...   2020
# 7666                                    It's Just Us  ...   2020
# 7667                                       Tee em el  ...   2020
#
# [7668 rows x 18 columns]

# %%
# Sorting date by gross Earning

df = df.sort_values(by='gross',inplace=False, ascending=False)

df.head()
# Out:
#                                             name  ...   Year
# 5445                                      Avatar  ...   2009
# 7445                           Avengers: Endgame  ...   2019
# 3045                                     Titanic  ...   1997
# 6663  Star Wars: Episode VII - The Force Awakens  ...   2015
# 7244                      Avengers: Infinity War  ...   2018
#
# [5 rows x 18 columns]

# %%
# Setting to show how many rows to display
pd.set_option('display.max_rows',100)
# pd.set_option('display.max_rows',none)

# %%
# Drop any duplicates

df['company'].drop_duplicates()
# Out:
# 5445       Twentieth Century Fox
# 7445              Marvel Studios
# 6663                   Lucasfilm
# 7480        Walt Disney Pictures
# 6653          Universal Pictures
#                   ...
# 1635               Charlie Mopic
# 1631          Double Helix Films
# 1617     Gibraltar Entertainment
# 1601    Budapest Stúdió Vállalat
# 7667                 PK 65 Films
# Name: company, Length: 2386, dtype: object

# %%
# Drop any duplicate across entire data frame

df.drop_duplicates()
# Out:
#                                             name  ...   Year
# 5445                                      Avatar  ...   2009
# 7445                           Avengers: Endgame  ...   2019
# 3045                                     Titanic  ...   1997
# 6663  Star Wars: Episode VII - The Force Awakens  ...   2015
# 7244                      Avengers: Infinity War  ...   2018
# ...                                          ...  ...    ...
# 1617                             Mortal Passions  ...   1990
# 1614                              Edge of Sanity  ...   1989
# 1606                                   I, Madman  ...   1989
# 1601                        My Twentieth Century  ...   1990
# 7667                                   Tee em el  ...   2020
#
# [7668 rows x 18 columns]

# %%
# Hypothesis: columns budget and company may have high correlation to the gross
# Scatter plot with budget vs gross

plt.scatter(x=df['budget'], y=df['gross'])

plt.title('Budget vs Gross Earnings')

plt.xlabel('Budget for Film')

plt.ylabel('Gross Earning')

plt.show()

# %%
# Plot budget vs gross using seaborn

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color":"red"}, line_kws={"color":"blue"})

# %%
# Find correlation
# corr() only working on numerical values
# Three method: pearson, kendall, spearman

df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.092616  0.222427  0.309212  0.261900  0.116358
# score    0.092616  1.000000  0.407101  0.056863  0.186012  0.394564
# votes    0.222427  0.407101  1.000000  0.486931  0.632870  0.306984
# budget   0.309212  0.056863  0.486931  1.000000  0.750157  0.268372
# gross    0.261900  0.186012  0.632870  0.750157  1.000000  0.244339
# runtime  0.116358  0.394564  0.306984  0.268372  0.244339  1.000000

# %%
# Correlation between budget and gross = 0.750157 with is the highes number

# %%
correlation_matrix = df.corr(method='pearson')

sns.heatmap(correlation_matrix,annot=True)

plt.title('Correlation Matric for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.show()

# %%
# Turn non-numerical data to numbers

df_numerical = df

for col_name in df_numerical.columns:
  if(df_numerical[col_name].dtype == 'object'):
    df_numerical[col_name] = df_numerical[col_name].astype('category')
    df_numerical[col_name] = df_numerical[col_name].cat.codes

df_numerical
# Out:
#       name  rating  genre  year  ...  runtime  releasedDate  releasedYear  Year
# 5445   533       6      0  2009  ...    162.0            87           335    29
# 7445   535       6      0  2019  ...    181.0            32           520    39
# 3045  6896       6      6  1997  ...    194.0            88           146    17
# 6663  5144       6      0  2015  ...    138.0            87           459    35
# 7244   536       6      0  2018  ...    149.0            33           504    38
# ...    ...     ...    ...   ...  ...      ...           ...           ...   ...
# 1617  3712       7      5  1989  ...     92.0           162            89    10
# 1614  1745       7     10  1989  ...     85.0            16            79     9
# 1606  2691       7      8  1989  ...     89.0            41            79     9
# 1601  3836       0      4  1989  ...    104.0           146            84    10
# 7667  5394       0     10  2020  ...    102.0            54           526    40
#
# ...

# %%
correlation_matrix = df_numerical.corr(method='pearson')

sns.heatmap(correlation_matrix,annot=True)

plt.title('Correlation Matric for Numeric Features')

plt.xlabel('Movie Features')

plt.ylabel('Movie Features')

plt.rcParams['figure.figsize'] = [12, 12]

plt.show()

# %%
correlation_mat = df_numerical.corr()

corr_pairs = correlation_mat.unstack()

corr_pairs
# Out:
# name  name            1.000000
#       rating         -0.008069
#       genre           0.016355
#       year            0.011453
#       released       -0.011311
#                         ...
# Year  company        -0.009185
#       runtime         0.121206
#       releasedDate   -0.004669
#       releasedYear    0.985065
#       Year            1.000000
# Length: 324, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values()

sorted_pairs
# Out:
# genre    budget    -0.334021
# budget   genre     -0.334021
# gross    genre     -0.234297
# genre    gross     -0.234297
# votes    genre     -0.145296
#                       ...
# gross    gross      1.000000
# company  company    1.000000
# runtime  runtime    1.000000
# writer   writer     1.000000
# Year     Year       1.000000
# Length: 324, dtype: float64

# %%
high_corr = sorted_pairs[(sorted_pairs)>0.5]

high_corr
# Out:
# gross         votes           0.632870
# votes         gross           0.632870
# gross         budget          0.750157
# budget        gross           0.750157
# year          releasedYear    0.980716
# releasedYear  year            0.980716
#               Year            0.985065
# Year          releasedYear    0.985065
#               year            0.992136
# year          Year            0.992136
# released      releasedDate    0.999759
# releasedDate  released        0.999759
# name          name            1.000000
# releasedDate  releasedDate    1.000000
# rating        rating          1.000000
# genre         genre           1.000000
# year          year            1.000000
# released      released        1.000000
# score         score           1.000000
# votes         votes           1.000000
# releasedYear  releasedYear    1.000000
# director      director        1.000000
# star          star            1.000000
# country       country         1.000000
# ...

# %%
# Year, Votes and Budget have the highest correlation to the gross earning
